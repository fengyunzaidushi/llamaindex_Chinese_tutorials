# %% [markdown]
# <a href="https://colab.research.google.com/github/jerryjliu/llama_index/blob/main/docs/examples/index_structs/doc_summary/DocSummary.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Document Summary Index
#
# This demo showcases the document summary index, over Wikipedia articles on different cities.
#
# The document summary index will extract a summary from each document and store that summary, as well as all nodes corresponding to the document.
#
# Retrieval can be performed through the LLM or embeddings (which is a TODO). We first select the relevant documents to the query based on their summaries. All retrieved nodes corresponding to the selected documents are retrieved.

# %% [markdown]
# If you're opening this Notebook on colab, you will probably need to install LlamaIndex 🦙.

# %%
# !pip install llama-index

# %%
# !pip show openai
# Out:
# Name: openai
# Version: 1.3.7
# Summary: The official Python library for the openai API
# Home-page:
# Author:
# Author-email: OpenAI <support@openai.com>
# License:
# Location: /opt/miniconda3/envs/py310_chat/lib/python3.10/site-packages
# Requires: anyio, distro, httpx, pydantic, sniffio, tqdm, typing-extensions
# Required-by: instructor, litellm, llama-index, open-interpreter, pandasai, pyautogen

# %%
import os
import openai

# os.environ["OPENAI_API_KEY"]="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"
# openai.api_key = os.environ["OPENAI_API_KEY"]

# %%
api_key1=os.environ['openai_api_key1']

# %%
api_key1
# Out:
# 'sk-A2IJsOOcVEjwYlph31BaB9B48cBf459bA4D3212b48D2Ed83'

# %%
import logging
import sys

logging.basicConfig(stream=sys.stdout, level=logging.WARNING)
logging.getLogger().addHandler(logging.StreamHandler(stream=sys.stdout))

# # Uncomment if you want to temporarily disable logger
# logger = logging.getLogger()
# logger.disabled = True

# %%
import nest_asyncio

nest_asyncio.apply()

# %%
from llama_index import (
    SimpleDirectoryReader,
    ServiceContext,
    get_response_synthesizer,
)
from llama_index.indices.document_summary import DocumentSummaryIndex
from llama_index.llms import OpenAI

# %% [markdown]
# ### Load Datasets
#
# Load Wikipedia pages on different cities

# %%
wiki_titles = ["Toronto", "Seattle", "Chicago", "Boston", "Houston"]

# %%
from pathlib import Path

import requests

for title in wiki_titles:
    response = requests.get(
        "https://en.wikipedia.org/w/api.php",
        params={
            "action": "query",
            "format": "json",
            "titles": title,
            "prop": "extracts",
            # 'exintro': True,
            "explaintext": True,
        },
    ).json()
    page = next(iter(response["query"]["pages"].values()))
    wiki_text = page["extract"]

    data_path = Path("data")
    if not data_path.exists():
        Path.mkdir(data_path)

    with open(data_path / f"{title}.txt", "w") as fp:
        fp.write(wiki_text)

# %%
# Load all wiki documents
city_docs = []
for wiki_title in wiki_titles[:1]:
    docs = SimpleDirectoryReader(
        input_files=[f"data-zh/{wiki_title}.txt"]
    ).load_data()
    docs[0].doc_id = wiki_title
    city_docs.extend(docs)

# %%
city_docs
# Out:
# [Document(id_='Toronto', embedding=None, metadata={'file_path': 'data-zh/Toronto.txt', 'file_name': 'Toronto.txt', 'file_type': 'text/plain', 'file_size': 71081, 'creation_date': '2024-01-03', 'last_modified_date': '2024-01-03', 'last_accessed_date': '2024-01-03'}, excluded_embed_metadata_keys=['file_name', 'file_type', 'file_size', 'creation_date', 'last_modified_date', 'last_accessed_date'], excluded_llm_metadata_keys=['file_name', 'file_type', 'file_size', 'creation_date', 'last_modified_date', 'last_accessed_date'], relationships={}, hash='1759bb8756d42cef8fdaa021eb42d5bab5b0481fb2429309b5b242b35a55cf4f', text="多伦多是加拿大人口最多的城市，也是加拿大安大略省的省会城市。2021 年有记录的人口为 2,794,356 人，是北美人口第四多的城市。该市是金马蹄城市群的支柱，金马蹄城市群围绕安大略湖西端，人口为 9,765,188 人（截至 2021 年），而大多伦多地区 2021 年人口为 6,712,341 人。多伦多是国际商业、金融、艺术、体育和文化中心，是世界上最具多元文化和国际化的城市之一。多伦多地区是原住民穿越和居住的地方，地处广阔的斜坡高原，河流纵横交错。 、深谷、城市森林，已有一万多年的历史。在备受争议的多伦多购买案之后，密西沙加将该地区交给英国王室，英国人于 1793 年建立了约克镇，后来将其指定为上加拿大的首府。1812年战争期间，该镇是约克战役的所在地，遭受美军的严重破坏。1834 年，约克更名为多伦多市。1867年加拿大联邦期间，它被指定为安大略省的首府。此后，该市通过吞并和合并，超出了最初的范围，目前面积为 630.2 平方公里（243.3 平方英里）。\n多伦多的多元化人口反映了其作为加拿大移民的重要目的地的当前和历史角色。大约一半的居民出生在加拿大境外，居民中有 200 多个种族。虽然大多数多伦多人以英语为主要语言，但该市使用 160 多种语言。多伦多市长由民众直接投票选出，担任该市的行政长官。多伦多市议会是一院制立法机构，自 2018 年市政选举以来，由 25 名议员组成，代表全市的地理选区。多伦多是著名的音乐、戏剧、电影制作和电视制作中心，也是总部所在地加拿大主要的国家广播网络和媒体机构。其多样化的文化机构，包括众多的博物馆和画廊、节日和公共活动、娱乐区、国家历史遗址和体育活动，每年吸引超过 4300 万游客。多伦多以其众多的摩天大楼和高层建筑而闻名，尤其是亚洲以外陆地上最高的独立式建筑加拿大国家电视塔。这座城市是多伦多证券交易所的所在地，是加拿大五家最大银行的总部，许多加拿大大型企业和跨国公司的总部。其经济高度多元化，在技术、设计、金融服务、生命科学、教育、艺术、时尚、航空航天、环境创新、食品服务和旅游业方面具有优势。多伦多是北美第三大科技中心，仅次于硅谷和纽约市，也是发展最快的中心。\n\n\n==地名==\n\n多伦多一词在法语和英语中有多种拼写，包括 Tarento、Tarontha、Taronto、Toranto、Torento、Toronto 和 Toronton。塔伦托指的是“海峡”，这是锡姆科湖流入库奇钦湖的一条水道，休伦人曾在那里种植树苗来圈养鱼类。这条狭窄地带被莫霍克人称为“tkaronto”，意思是“水中有树木的地方”，早在 1615 年塞缪尔·德·尚普兰 (Samuel de Champlain) 就有了记录。“Toronto”一词的意思是“充足”，也出现在 1632 年休伦语法语词典中，休伦语也是易洛魁语的一种。它也出现在法国地图上，指的是不同的地点，包括乔治亚湾、锡姆科湖和几条河流。从安大略湖到休伦湖的一条运输路线途经此地，被称为多伦多运输地点小道，导致了这个名字的广泛使用。\n这座城市的发音大致为 tə-RON-toh，当地人将其理解为 [təˈɹɒno] 或 [ˈtʃɹɒno]，第二个“t”不发音。\n\n\n==历史==\n\n\n===早期历史===\n\n多伦多的所在地位于西北最古老路线之一的入口处，这条路线为休伦族、易洛魁族和奥及布威族所知并使用。考古遗址显示了数千年前人类占领的证据。从安大略有记录的历史开始，该地点就具有重要的战略意义。 1660 年代，易洛魁人在今天的多伦多境内建立了两个村庄：位于胭脂河 (Rouge River) 河畔的 Ganatsekwyagon（珠子山）和位于亨伯河 (Humber River) 河畔的 Teiaiagon 。到 1701 年，密西沙加人取代了易洛魁人，易洛魁人在海狸战争结束时放弃了多伦多地区，大多数人返回了位于现今纽约州的家乡。法国商人于 1750 年建立了鲁耶堡（目前的展览场地是后来在那里发展起来），但在 1759 年七年战争期间放弃了它。英国在战争中击败了法国及其本土盟友，该地区于 1763 年成为英国殖民地魁北克的一部分。\n美国独立战争期间，随着联合帝国保皇派逃往安大略湖以北英国控制的土地，大批英国定居者涌入这里。国王授予他们土地以补偿他们在十三殖民地的损失。新的上加拿大省正在创建，需要一个首都。1787年，英国多切斯特勋爵与新信贷第一民族的密西沙加人安排了多伦多购买案，从而获得了多伦多地区超过25万英亩（1000平方公里）的土地。多切斯特打算将这个地点命名为多伦多。多伦多购买后的头 25 年里很平静，尽管该地区“偶尔有独立毛皮商人”，通常抱怨放荡和酗酒。 1793 年，总督约翰·格雷夫斯·西姆科 (John Graves Simcoe) 在多伦多购买中建立了约克镇土地，以约克公爵和奥尔巴尼公爵弗雷德里克王子的名字命名。西姆科决定将上加拿大首府从纽瓦克（滨湖尼亚加拉）迁至约克，因为他相信新地点不会那么容易受到美国的攻击。约克驻军建在该镇天然港口的入口处，周围有一个长长的沙洲半岛。该镇的定居点形成于半岛后面的港口东端，靠近现在的议会街和前街交叉口（在“老城区”区域）。\n\n\n=== 19 世纪 ===\n1813 年，作为 1812 年战争的一部分，约克战役以美军占领和掠夺该镇而告终。约翰·斯特拉坎通过谈判达成了该镇的投降。美国士兵在五天的占领期间摧毁了大部分驻军并放火焚烧了议会大楼。由于约克被洗劫，英国军队在战争后期以焚烧华盛顿特区作为报复\n约克于 1834 年 3 月 6 日成立为多伦多市，并采用原住民名称。改革派政治家威廉·里昂·麦肯齐成为多伦多第一任市长。麦肯齐后来领导了 1837 年反对英国殖民政府的上加拿大起义，但没有成功。\n多伦多的 9,000 人口包括一些非洲裔美国奴隶（其中一些是由效忠派带来的）和黑人效忠派（他们被国王释放）（后者大多数被重新安置在新斯科舍省）。到 1834 年，来自美国南部的难民奴隶也移民到多伦多以获得自由。1834 年，奴隶制在上加拿大（以及整个大英帝国）被彻底禁止。多伦多人将有色人种融入他们的社会。1840 年代，位于早期城市商业繁荣的弗雷德里克街和国王街的一家餐馆由一位名叫布洛克瑟姆 (Bloxom) 的黑人经营。\n作为加拿大移民的主要目的地，这座城市在 19 世纪余下的时间里迅速发展。第一波重要的移民是逃离爱尔兰大饥荒的爱尔兰人。他们大多数是天主教徒。到 1851 年，爱尔兰出生的人口已成为该市最大的单一族裔群体。苏格兰和英格兰人口欢迎少量的新教爱尔兰移民，其中一些来自现在的北爱尔兰，这使橙色勋章对多伦多社会产生了重大而持久的影响。1850 年至 1950 年间，几乎多伦多的每一位市长都是橙色勋章的成员，由于橙色勋章对城市政治和行政的影响，这座城市有时被称为“加拿大的贝尔法斯特”。在短时间内，多伦多的地位是首都的两倍加拿大联合省的省会：首先从 1849 年至 1851 年，蒙特利尔发生骚乱后，后来从 1855 年至 1859 年。此后，魁北克被指定为首都，直至 1865 年（加拿大联邦成立前两年）。从那时起，魁北克省被指定为首都。加拿大仍然是安大略省渥太华。\n多伦多于 1867 年正式成立后成为安大略省的首府。安大略省政府所在地曾短暂回到上加拿大第三议会大厦所在的同一栋大楼，然后于 2017 年迁至皇后公园的安大略省立法大楼。 1893年。由于其省会地位，该市也是总督府的所在地，总督府是安大略省右侧皇家总督代表的住所。\n早在1876年加拿大皇家军事学院成立之前，这一概念的支持者就提出在加拿大设立军事学院。由英国正规军组成的成年男学生在多伦多军事教育学院接受了为期三个月的军事课程。1864年根据民兵总令建立，学校使民兵军官或民兵委任或晋升候选人能够学习军事职责、训练和纪律，在营训练中指挥一个连，在连训练中训练一个连，在内部训练中训练连。公司的经济以及公司高管的职责。1867 年，该学校保留在联邦。1868 年，骑兵和炮兵教育学校在多伦多成立。\n19 世纪，该 ...

# %% [markdown]
# ### Build Document Summary Index
#
# We show two ways of building the index:
# - default mode of building the document summary index
# - customizing the summary query

# %%
api_base1="https://aigc789.top/v1"

# %%
api_base2="https://api.aigc369.com/v1"

# %%
# LLM (gpt-3.5-turbo)
chatgpt = OpenAI(temperature=0, model="gpt-3.5-turbo",api_base=api_base1,api_key=api_key1)
service_context = ServiceContext.from_defaults(llm=chatgpt, chunk_size=1024)

# %%
# default mode of building the index
response_synthesizer = get_response_synthesizer(
    response_mode="tree_summarize", use_async=True
)
doc_summary_index = DocumentSummaryIndex.from_documents(
    city_docs,
    service_context=service_context,
    response_synthesizer=response_synthesizer,
    show_progress=True,
)
# Out:
# Parsing nodes:   0%|          | 0/1 [00:00<?, ?it/s]
# Summarizing documents:   0%|          | 0/1 [00:00<?, ?it/s]
# current doc id: Toronto
# Generating embeddings:   0%|          | 0/1 [00:00<?, ?it/s]

# %%
doc_summary_index.get_document_summary("Toronto")
# Out:
# "The provided text is about the city of Toronto in Canada. It covers various aspects of the city, including its population, history, economy, cultural diversity, landmarks, architecture, climate, parks, neighborhoods, suburbs, industrial areas, healthcare, education, sports, government, crime rates, transportation system, and major events. The text provides information on topics such as the city's population statistics, ethnic composition, languages spoken, economic sectors, real estate market, technology and biotechnology industries, tourism attractions, educational institutions, healthcare facilities, sports teams, government structure, crime rates, transportation infrastructure, and major events hosted by Toronto.\n\nSome of the questions that this text can answer include:\n- What is the population of Toronto and its population density?\n- What are the major ethnic groups and languages spoken in Toronto?\n- What is the economic significance of Toronto and what industries are prominent?\n- What are some popular tourist attractions in Toronto?\n- What are the options for primary and secondary education in Toronto?\n- What universities and colleges are located in Toronto?\n- What healthcare facilities are available in Toronto?\n- What sports teams are based in Toronto and what stadiums do they play in?\n- How is Toronto governed?\n- What is the crime rate in Toronto?\n- What is the transportation system like in Toronto?\n- What are the major highways and roads in Toronto?\n- What are the airports serving Toronto?\n- What are some of the crime statistics and trends in Toronto?\n- What were the significant events in Toronto's history?\n- How has the waterfront of Toronto been developed over time?\n- What are some of the neighborhoods and suburbs in Toronto?\n- How has the industrial landscape of Toronto evolved?\n- What are some notable architectural landmarks in Toronto?\n- What is the climate like in Toronto?\n- What parks are there in Toronto and what activities can be done in them?\n- What is the real estate market like in Toronto?\n- What is the significance of Toronto in the technology and biotechnology industries?\n- What are some of the healthcare institutions in Toronto?\n- How many branches does the Toronto Public Library have?\n- What cultural and performing arts venues are located in Toronto?\n- What are some of the major events and festivals that take place in Toronto?\n- What is the role of Toronto in the media and entertainment industry?\n- What are some of the non-profit organizations focused on health in Toronto?\n- What is the current status of technology and biotechnology in Toronto?\n- What was the significance of the 2015 Pan American Games in Toronto?\n- How does Toronto's homicide rate compare to other cities in Canada and the United States?\n- How has gun violence in Toronto changed over the years?"

# %%
doc_summary_index.storage_context.persist("index-zh")

# %%
from llama_index.indices.loading import load_index_from_storage
from llama_index import StorageContext

# rebuild storage context
storage_context = StorageContext.from_defaults(persist_dir="index-zh")
doc_summary_index = load_index_from_storage(storage_context)

# %% [markdown]
# ### Perform Retrieval from Document Summary Index
#
# We show how to execute queries at a high-level. We also show how to perform retrieval at a lower-level so that you can view the parameters that are in place. We show both LLM-based retrieval and embedding-based retrieval using the document summaries.

# %% [markdown]
# #### High-level Querying
#
# Note: this uses the default, embedding-based form of retrieval

# %%
query_engine = doc_summary_index.as_query_engine(
    response_mode="tree_summarize", use_async=True
)

# %%
response = query_engine.query("What are the sports teams in Toronto?")

# %%
print(response)
# Out:
# The sports teams in Toronto include the Toronto Maple Leafs (ice hockey), Toronto Raptors (basketball), Toronto Blue Jays (baseball), Toronto FC (soccer), and Toronto Argonauts (Canadian football).

# %% [markdown]
# #### LLM-based Retrieval

# %%
from llama_index.indices.document_summary import (
    DocumentSummaryIndexLLMRetriever,
)

# %%
retriever = DocumentSummaryIndexLLMRetriever(
    doc_summary_index,
    # choice_select_prompt=None,
    # choice_batch_size=10,
    # choice_top_k=1,
    # format_node_batch_fn=None,
    # parse_choice_select_answer_fn=None,
    # service_context=None
)

# %%
retrieved_nodes = retriever.retrieve("What are the sports teams in Toronto?")

# %%
print(len(retrieved_nodes))
# Out:
# 20

# %%
print(retrieved_nodes[0].score)
print(retrieved_nodes[0].node.get_text())
# Out:
# 10.0
# Toronto is the most populous city in Canada and the capital city of the Canadian province of Ontario. With a recorded population of 2,794,356 in 2021, it is the fourth-most populous city in North America. The city is the anchor of the Golden Horseshoe, an urban agglomeration of 9,765,188 people (as of 2021) surrounding the western end of Lake Ontario, while the Greater Toronto Area proper had a 2021 population of 6,712,341. Toronto is an international centre of business, finance, arts, sports and culture, and is recognized as one of the most multicultural and cosmopolitan cities in the world.Indigenous peoples have travelled through and inhabited the Toronto area, located on a broad sloping plateau interspersed with rivers, deep ravines, and urban forest, for more than 10,000 years. After the broadly disputed Toronto Purchase, when the Mississauga surrendered the area to the British Crown, the British established the town of York in 1793 and later designated it as the capital of Upper Canada. During the War of 1812, the town was the site of the Battle of York and suffered heavy damage by American troops. York was renamed and incorporated in 1834 as the city of Toronto. It was designated as the capital of the province of Ontario in 1867 during Canadian Confederation. The city proper has since expanded past its original limits through both annexation and amalgamation to its current area of 630.2 km2 (243.3 sq mi).
# The diverse population of Toronto reflects its current and historical role as an important destination for immigrants to Canada. More than half of residents were born outside of Canada, more than half of residents belong to a visible minority group, and over 200 distinct ethnic origins are represented among its inhabitants. While the majority of Torontonians speak English as their primary language, over 160 languages are spoken in the city. The mayor of Toronto is elected by direct popular vote to serve as the chief executive of the city. The Toronto City Council is a unicameral legislative body, comprising 25 councillors since the 2018 municipal election, representing geographical wards throughout the city.Toronto is a prominent centre for music, theatre, motion picture production, and television production, and is home to the headquarters of Canada's major national broadcast networks and media outlets. Its varied cultural institutions, which include numerous museums and galleries, festivals and public events, entertainment districts, national historic sites, and sports activities, attract over 43 million tourists each year. Toronto is known for its many skyscrapers and high-rise buildings, in particular the tallest free-standing structure on land outside of Asia, the CN Tower.The city is home to the Toronto Stock Exchange, the headquarters of Canada's five largest banks, and the headquarters of many large Canadian and multinational corporations. Its economy is highly diversified with strengths in technology, design, financial services, life sciences, education, arts, fashion, aerospace, environmental innovation, food services, and tourism. Toronto is the third-largest tech hub in North America after Silicon Valley and New York City, and the fastest growing.
#
#
# == Toponymy ==
#
# The word Toronto has been recorded with various spellings in French and English, including Tarento, Tarontha, Taronto, Toranto, Torento, Toronto, and Toronton. Taronto referred to "The Narrows", a channel of water through which Lake Simcoe discharges into Lake Couchiching where the Huron had planted tree saplings to corral fish. This narrows was called tkaronto by the Mohawk, meaning "where there are trees standing in the water," and was recorded as early as 1615 by Samuel de Champlain. The word "Toronto", meaning "plenty" also appears in a 1632 French lexicon of the Huron language, which is also an Iroquoian language. It also appears on French maps referring to various locations, including Georgian Bay, Lake Simcoe, and several rivers. A portage route from Lake Ontario to Lake Huron running through this point, known as the Toronto Carrying-Place Trail, led to widespread use of the name.
# The pronunciation of the city is broadly   tə-RON-toh, which locals realize as [təˈɹɒno] or [ˈtʃɹɒno], leaving the second 't' silent.
#
#
# == History ==

# %%
# use retriever as part of a query engine
from llama_index.query_engine import RetrieverQueryEngine

# configure response synthesizer
response_synthesizer = get_response_synthesizer(response_mode="tree_summarize")

# assemble query engine
query_engine = RetrieverQueryEngine(
    retriever=retriever,
    response_synthesizer=response_synthesizer,
)

# query
response = query_engine.query("What are the sports teams in Toronto?")
print(response)
# Out:
# The sports teams in Toronto include the Toronto Maple Leafs (NHL), Toronto Raptors (NBA), Toronto Blue Jays (MLB), Toronto FC (MLS), and Toronto Argonauts (CFL).

# %% [markdown]
# #### Embedding-based Retrieval

# %%
from llama_index.indices.document_summary import (
    DocumentSummaryIndexEmbeddingRetriever,
)

# %%
retriever = DocumentSummaryIndexEmbeddingRetriever(
    doc_summary_index,
    # similarity_top_k=1,
)

# %%
retrieved_nodes = retriever.retrieve("What are the sports teams in Toronto?")

# %%
len(retrieved_nodes)
# Out:
# 20

# %%
print(retrieved_nodes[0].node.get_text())
# Out:
# Toronto is the most populous city in Canada and the capital city of the Canadian province of Ontario. With a recorded population of 2,794,356 in 2021, it is the fourth-most populous city in North America. The city is the anchor of the Golden Horseshoe, an urban agglomeration of 9,765,188 people (as of 2021) surrounding the western end of Lake Ontario, while the Greater Toronto Area proper had a 2021 population of 6,712,341. Toronto is an international centre of business, finance, arts, sports and culture, and is recognized as one of the most multicultural and cosmopolitan cities in the world.Indigenous peoples have travelled through and inhabited the Toronto area, located on a broad sloping plateau interspersed with rivers, deep ravines, and urban forest, for more than 10,000 years. After the broadly disputed Toronto Purchase, when the Mississauga surrendered the area to the British Crown, the British established the town of York in 1793 and later designated it as the capital of Upper Canada. During the War of 1812, the town was the site of the Battle of York and suffered heavy damage by American troops. York was renamed and incorporated in 1834 as the city of Toronto. It was designated as the capital of the province of Ontario in 1867 during Canadian Confederation. The city proper has since expanded past its original limits through both annexation and amalgamation to its current area of 630.2 km2 (243.3 sq mi).
# The diverse population of Toronto reflects its current and historical role as an important destination for immigrants to Canada. More than half of residents were born outside of Canada, more than half of residents belong to a visible minority group, and over 200 distinct ethnic origins are represented among its inhabitants. While the majority of Torontonians speak English as their primary language, over 160 languages are spoken in the city. The mayor of Toronto is elected by direct popular vote to serve as the chief executive of the city. The Toronto City Council is a unicameral legislative body, comprising 25 councillors since the 2018 municipal election, representing geographical wards throughout the city.Toronto is a prominent centre for music, theatre, motion picture production, and television production, and is home to the headquarters of Canada's major national broadcast networks and media outlets. Its varied cultural institutions, which include numerous museums and galleries, festivals and public events, entertainment districts, national historic sites, and sports activities, attract over 43 million tourists each year. Toronto is known for its many skyscrapers and high-rise buildings, in particular the tallest free-standing structure on land outside of Asia, the CN Tower.The city is home to the Toronto Stock Exchange, the headquarters of Canada's five largest banks, and the headquarters of many large Canadian and multinational corporations. Its economy is highly diversified with strengths in technology, design, financial services, life sciences, education, arts, fashion, aerospace, environmental innovation, food services, and tourism. Toronto is the third-largest tech hub in North America after Silicon Valley and New York City, and the fastest growing.
#
#
# == Toponymy ==
#
# The word Toronto has been recorded with various spellings in French and English, including Tarento, Tarontha, Taronto, Toranto, Torento, Toronto, and Toronton. Taronto referred to "The Narrows", a channel of water through which Lake Simcoe discharges into Lake Couchiching where the Huron had planted tree saplings to corral fish. This narrows was called tkaronto by the Mohawk, meaning "where there are trees standing in the water," and was recorded as early as 1615 by Samuel de Champlain. The word "Toronto", meaning "plenty" also appears in a 1632 French lexicon of the Huron language, which is also an Iroquoian language. It also appears on French maps referring to various locations, including Georgian Bay, Lake Simcoe, and several rivers. A portage route from Lake Ontario to Lake Huron running through this point, known as the Toronto Carrying-Place Trail, led to widespread use of the name.
# The pronunciation of the city is broadly   tə-RON-toh, which locals realize as [təˈɹɒno] or [ˈtʃɹɒno], leaving the second 't' silent.
#
#
# == History ==

# %%
# use retriever as part of a query engine
from llama_index.query_engine import RetrieverQueryEngine

# configure response synthesizer
response_synthesizer = get_response_synthesizer(response_mode="tree_summarize")

# assemble query engine
query_engine = RetrieverQueryEngine(
    retriever=retriever,
    response_synthesizer=response_synthesizer,
)

# query
response = query_engine.query("What are the sports teams in Toronto?")
print(response)
# Out:
# The sports teams in Toronto include the Toronto Maple Leafs (NHL), Toronto Raptors (NBA), Toronto Blue Jays (MLB), Toronto FC (MLS), Toronto Argonauts (CFL), Toronto Rock (NLL), Toronto Wolfpack (Rugby Football League), Toronto Six (NWHL), and Toronto Rush (American Ultimate Disc League).
